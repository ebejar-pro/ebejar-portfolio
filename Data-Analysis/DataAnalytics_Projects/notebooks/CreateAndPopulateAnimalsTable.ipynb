# %%
import sqlite3

# Connect to SQLite database (creates file if it doesn't exist)
conn = sqlite3.connect("animals.db")

cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS animals (
    animal_id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    species TEXT,
    age INTEGER,
    habitat TEXT
);
""")

conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Paths
BASE_DIR = Path.cwd().parent
CSV_PATH = BASE_DIR / "data" / "raw" / "animals.csv"
DB_PATH  = BASE_DIR / "data" / "animals.db"

# Check CSV Path exists
if not CSV_PATH.exists():
    raise FileNotFoundError(f"CSV not found at: {CSV_PATH}")

# Load CSV
df = pd.read_csv(CSV_PATH)

# Check if null is found or age is negative 
assert df.isnull().sum().sum() == 0, "Null values found!"
assert (df["age"] >= 0).all(), "Invalid age detected!"

# Connect to SQLite
conn = sqlite3.connect(DB_PATH)

# Insert data
df.to_sql(
    name="animals",
    con=conn,
    if_exists="append",
    index=False
)

# Close connection
conn.commit()
conn.close()

print("✅ Data successfully inserted into animals table.")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[3], line 25
#      22 conn = sqlite3.connect(DB_PATH)
#      24 # Insert data
# ---> 25 df.to_sql(
#      26     name="animals",
#      27     con=conn,
#      28     if_exists="append",
#      29     index=False
#      30 )
#      32 # Close connection
#      33 conn.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
# Out:
# UsageError: Cell magic `%%sql` not found.
