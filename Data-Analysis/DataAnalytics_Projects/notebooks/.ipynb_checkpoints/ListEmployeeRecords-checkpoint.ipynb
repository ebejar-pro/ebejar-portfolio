# %%
import sqlite3
import os

# Create the directory if it doesn't already exist
if not os.path.exists('data'):
    os.makedirs('data')
    
connection = sqlite3.connect(r'C:\Users\elbej\OneDrive\Documents\GitHub\ebejar-portfolio\Data-Analysis\DataAnalytics_Projects\data\employee_records.db')
cursor = connection.cursor()
cursor.execute('SELECT * FROM employees')
cursor.fetchall()
# Out:
# [(101, 'Rai', 'Developer', 750000.0),
#  (102, 'Bobby', 'Manager', 850000.0),
#  (103, 'Charles', 'Analyst', 650000.0)]
