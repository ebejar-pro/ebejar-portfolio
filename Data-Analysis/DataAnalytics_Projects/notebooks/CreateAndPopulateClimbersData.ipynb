# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Connect to SQLite database (creates file if it doesn't exist)
conn = sqlite3.connect("climbers.db")

cursor = conn.cursor()
 # Create climbers table
cursor.execute('''
        CREATE TABLE IF NOT EXISTS climbers (
            id INTEGER PRIMARY KEY,
            climbers_name TEXT,
            nationality TEXT,
            successful_climbs INTEGER,
            failed_climbs INTEGER,
            date_of_first_ascent DATE,
            date_of_last_ascent DATE
        )
        ''')
conn.commit()
conn.close()

# Load data from CSV into DataFrame
# Paths
BASE_DIR = Path.cwd().parent
CSV_PATH = BASE_DIR / "data" / "raw" / "climbers.csv"
DB_PATH  = BASE_DIR / "data" / "climbers.db"

# Check CSV Path exists
if not CSV_PATH.exists():
    raise FileNotFoundError(f"CSV not found at: {CSV_PATH}")

# Load CSV
df = pd.read_csv(CSV_PATH)

# Connect to SQLite
conn = sqlite3.connect(DB_PATH)

# Insert data
df.to_sql(
    name="climbers",
    con=conn,
    if_exists="append",
    index=False
)

# Close connection
conn.commit()
conn.close()

print("✅ Data successfully inserted into climbers table.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 41
#      38 conn = sqlite3.connect(DB_PATH)
#      40 # Insert data
# ---> 41 df.to_sql(
#      42     name="climbers",
#      43     con=conn,
#      44     if_exists="append",
#      45     index=False
#      46 )
#      48 # Close connection
#      49 conn.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
