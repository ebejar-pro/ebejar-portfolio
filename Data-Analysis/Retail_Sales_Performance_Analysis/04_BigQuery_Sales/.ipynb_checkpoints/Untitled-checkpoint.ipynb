# %%
import pandas as pd
from faker import Faker
from google.cloud import bigquery
import os


# 1. AUTHENTICATION (Replace with your JSON key path)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/elbej/bq-analysis-04-9ce735113ac2.json"

# 2. GENERATE SYNTHETIC RETAIL DATA
fake = Faker()
data = []
for _ in range(100):  # Generating 100 fake transactions
    data.append({
        "transaction_id": fake.uuid4(),
        "store_id": fake.random_int(min=1, max=20),
        "customer_id": f"CUST-{fake.random_int(1000, 9999)}",
        "transaction_timestamp": fake.date_time_this_month().isoformat(),
        "total_amount": round(fake.pyfloat(left_digits=3, right_digits=2, min_value=10, max_value=500), 2)
    })

df = pd.DataFrame(data)

# 3. UPLOAD TO BIGQUERY
client = bigquery.Client()
table_id = "bq-analysis-04.retail_bronze.raw_sales" # Dataset must exist first

job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND", # Adds new data to the bottom
    autodetect=True                   # Automatically detects schema/types
)

print(f"Uploading {len(df)} rows to {table_id}...")
job = client.load_table_from_dataframe(df, table_id, job_config=job_config)
job.result() # Wait for job to finish

print("✅ Success! Check your BigQuery console.")
# Out:
# Uploading 100 rows to bq-analysis-04.retail_bronze.raw_sales...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 34
#      28 job_config = bigquery.LoadJobConfig(
#      29     write_disposition="WRITE_APPEND", # Adds new data to the bottom
#      30     autodetect=True                   # Automatically detects schema/types
#      31 )
#      33 print(f"Uploading {len(df)} rows to {table_id}...")
# ---> 34 job = client.load_table_from_dataframe(df, table_id, job_config=job_config)
#      35 job.result() # Wait for job to finish
#      37 print("✅ Success! Check your BigQuery console.")
#
# File ~\anaconda3\envs\condaRetailSales\lib\site-packages\google\cloud\bigquery\client.py:2831, in Client.load_table_from_dataframe(self, dataframe, destination, num_retries, job_id, job_id_prefix, location, project, job_config, parquet_compression, timeout)
#    2823     raise ValueError(
#    2824         "Got unexpected source_format: '{}'. Currently, only PARQUET and CSV are supported".format(
#    2825             new_job_config.source_format
#    2826         )
#    2827     )
#    2829 if pyarrow is None and new_job_config.source_format == job.SourceFormat.PARQUET:
#    2830     # pyarrow is now the only supported parquet engine.
# -> 2831     raise ValueError("This method requires pyarrow to be installed")
#    2833 if location is None:
#    2834     location = self.location
#
# ValueError: This method requires pyarrow to be installed
